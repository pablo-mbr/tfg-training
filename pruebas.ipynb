# %%
from dataclasses import dataclass
from datetime import datetime

@dataclass
class MetricsValue:
    value: float
    value_name: str

@dataclass
class MetricsDto:
    name: str
    timestamp: datetime
    step: int
    step_type: str
    phase: str
    values: list[MetricsValue]

# %%
import tensorflow as tf
import json
import time 
import paho.mqtt.client as mqtt
import csv
import os
from datetime import datetime
from dataclasses import asdict

def buildDto(epoch, variation):
    train_dto = MetricsDto(
                name= "prueba",
                timestamp=datetime.now().isoformat(),
                step= epoch,
                step_type="epoch",
                phase="train",
                values=[
                    MetricsValue(value=2*(1+(variation/100)), value_name="prueba")
                ]
            )
    return train_dto

mqtt_client = mqtt.Client()
broker = 'localhost'
port = 1883
mqtt_client.connect(broker, port)
mqtt_client.loop_start()

for i in range(15):
    time.sleep(4)
    mqtt_client.publish("training/metrics", json.dumps(asdict(buildDto(i,0.14))), qos=1)
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_17832\172842867.py:23: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   mqtt_client = mqtt.Client()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      27 mqtt_client.loop_start()
#      29 for i in range(15):
# ---> 30     time.sleep(4)
#      31     mqtt_client.publish("training/metrics", json.dumps(asdict(buildDto(i,0.14))), qos=1)
#
# KeyboardInterrupt:
